# %%
import fastf1
fastf1.Cache.enable_cache("../data/cache")

# %%
session = fastf1.get_session(
    2026,
    "Monaco",
    "R"
)

# %%
session.load()
# Out:
# core           INFO 	Loading data for Monaco Grand Prix - Race [v3.8.3]
# req            INFO 	No cached data found for session_info. Loading data...
# _api           INFO 	Fetching session info data...
# req            INFO 	Data has been written to cache!
# req            INFO 	No cached data found for driver_info. Loading data...
# _api           INFO 	Fetching driver list...
# req            INFO 	Data has been written to cache!
# req            INFO 	No cached data found for session_status_data. Loading data...
# _api           INFO 	Fetching session status data...
# req            INFO 	Data has been written to cache!
# req            INFO 	No cached data found for lap_count. Loading data...
# _api           INFO 	Fetching lap count data...
# req            INFO 	Data has been written to cache!
# req            INFO 	No cached data found for track_status_data. Loading data...
# _api           INFO 	Fetching track status data...
# ...

# %%
session
type(session)
# Out:
# fastf1.core.Session

# %%
dir(session)
# Out:
# ['_QUALI_LIKE_SESSIONS',
#  '_RACE_LIKE_SESSIONS',
#  '_Session__fix_tyre_info',
#  '__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__firstlineno__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__static_attributes__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  '_add_first_lap_time_from_ergast',
#  '_add_track_status_to_laps',
#  '_calculate_quali_like_session_results',
#  '_calculate_race_like_session_results',
#  '_calculate_t0_date',
#  '_car_data',
#  '_check_lap_accuracy',
#  '_drivers_from_f1_api',
#  '_drivers_results_from_ergast',
#  '_ergast',
#  '_fix_missing_laps_retired_on_track',
#  '_get_property_warn_not_loaded',
#  '_laps',
#  '_load_drivers_results',
# ...

# %%
session.results.head()
# Out:
#    DriverNumber BroadcastName Abbreviation   DriverId         TeamName  \
# 12           12   K ANTONELLI          ANT  antonelli         Mercedes
# 44           44    L HAMILTON          HAM   hamilton          Ferrari
# 10           10       P GASLY          GAS      gasly           Alpine
# 6             6      I HADJAR          HAD     hadjar  Red Bull Racing
# 81           81     O PIASTRI          PIA    piastri          McLaren
#
#    TeamColor    TeamId FirstName   LastName        FullName  ... Position  \
# 12    00D7B6  mercedes      Kimi  Antonelli  Kimi Antonelli  ...      1.0
# 44    ED1131   ferrari     Lewis   Hamilton  Lewis Hamilton  ...      2.0
# 10    00A1E8    alpine    Pierre      Gasly    Pierre Gasly  ...      3.0
# 6     4781D7  red_bull     Isack     Hadjar    Isack Hadjar  ...      4.0
# 81    F47600   mclaren     Oscar    Piastri   Oscar Piastri  ...      5.0
#
#    ClassifiedPosition  GridPosition  Q1  Q2  Q3                   Time  \
# ...

# %%
session.laps.head()
# Out:
#                     Time Driver DriverNumber                LapTime  \
# 0 0 days 00:56:50.495000    NOR            1 0 days 00:01:30.629000
# 1 0 days 00:58:11.179000    NOR            1 0 days 00:01:20.684000
# 2 0 days 00:59:31.374000    NOR            1 0 days 00:01:20.195000
# 3 0 days 01:00:50.865000    NOR            1 0 days 00:01:19.491000
# 4 0 days 01:02:09.853000    NOR            1 0 days 00:01:18.988000
#
#    LapNumber  Stint PitOutTime PitInTime            Sector1Time  \
# 0        1.0    1.0        NaT       NaT                    NaT
# 1        2.0    1.0        NaT       NaT 0 days 00:00:21.738000
# 2        3.0    1.0        NaT       NaT 0 days 00:00:21.482000
# 3        4.0    1.0        NaT       NaT 0 days 00:00:21.206000
# 4        5.0    1.0        NaT       NaT 0 days 00:00:20.871000
#
#              Sector2Time  ... FreshTyre     Team           LapStartTime  \
# 0 0 days 00:00:39.379000  ...      True  McLaren 0 days 00:55:19.645000
# ...

# %%
session.weather_data.head()
# Out:
#                     Time  AirTemp  Humidity  Pressure  Rainfall  TrackTemp  \
# 0 0 days 00:00:24.792000     23.3      64.7    1022.1     False       33.1
# 1 0 days 00:01:24.809000     23.4      64.1    1022.0     False       34.0
# 2 0 days 00:02:24.794000     23.0      64.1    1022.0     False       34.0
# 3 0 days 00:03:24.789000     23.3      63.5    1022.1     False       34.4
# 4 0 days 00:04:24.791000     23.5      63.7    1022.1     False       35.1
#
#    WindDirection  WindSpeed
# 0            244        0.5
# 1              0        0.0
# 2              0        0.0
# 3              0        0.0
# 4            131        0.5

# %%
session.track_status.head()
# Out:
#                     Time Status   Message
# 0        0 days 00:00:00      1  AllClear
# 1 0 days 00:00:36.058000      2    Yellow
# 2 0 days 00:05:49.640000      1  AllClear
# 3 0 days 00:17:32.354000      2    Yellow
# 4 0 days 00:18:11.662000      1  AllClear

# %%
session.race_control_messages.head()
# Out:
#                  Time Category  \
# 0 2026-06-07 12:20:01     Flag
# 1 2026-06-07 12:22:10    Other
# 2 2026-06-07 12:25:25     Flag
# 3 2026-06-07 12:26:04     Flag
# 4 2026-06-07 12:30:01    Other
#
#                                              Message Status    Flag   Scope  \
# 0                        GREEN LIGHT - PIT EXIT OPEN   None   GREEN   Track
# 1  INCIDENT INVOLVING CAR 11 (PER) NOTED - FAILIN...   None    None    None
# 2                          YELLOW IN TRACK SECTOR 18   None  YELLOW  Sector
# 3                           CLEAR IN TRACK SECTOR 18   None   CLEAR  Sector
# 4                                    PIT EXIT CLOSED   None    None    None
#
#    Sector RacingNumber  Lap
# 0     NaN         None    1
# 1     NaN         None    1
# 2    18.0         None    1
# 3    18.0         None    1
# 4     NaN         None    1

# %%
lap = session.laps.pick_fastest()
lap.get_car_data()
# Out:
#                        Date      RPM  Speed  nGear  Throttle  Brake  DRS  \
# 0   2026-06-07 15:23:00.672  11679.0  263.0      6     100.0  False    0
# 1   2026-06-07 15:23:00.872  11824.0  265.0      6     100.0  False    0
# 2   2026-06-07 15:23:01.072  11905.0  267.0      6     100.0  False    0
# 3   2026-06-07 15:23:01.232  11870.0  267.0      6     100.0  False    0
# 4   2026-06-07 15:23:01.392  11911.0  268.0      6     100.0  False    0
# ..                      ...      ...    ...    ...       ...    ...  ...
# 269 2026-06-07 15:24:12.832  11144.0  252.0      6     100.0  False    0
# 270 2026-06-07 15:24:13.032  11292.0  254.0      6     100.0  False    0
# 271 2026-06-07 15:24:13.312  11395.0  256.0      6     100.0  False    0
# 272 2026-06-07 15:24:13.592  11539.0  260.0      6     100.0  False    0
# 273 2026-06-07 15:24:13.832  11609.0  262.0      6     100.0  False    0
#
#     Source                   Time            SessionTime
# ...

# %%
lap.get_pos_data
# Out:
# <bound method Lap.get_pos_data of Time                      0 days 03:16:21.840000
# Driver                                       ANT
# DriverNumber                                  12
# LapTime                   0 days 00:01:13.481000
# LapNumber                                   76.0
# Stint                                        5.0
# PitOutTime                                   NaT
# PitInTime                                    NaT
# Sector1Time               0 days 00:00:19.379000
# Sector2Time               0 days 00:00:34.566000
# Sector3Time               0 days 00:00:19.536000
# Sector1SessionTime        0 days 03:15:27.768000
# Sector2SessionTime        0 days 03:16:02.334000
# Sector3SessionTime        0 days 03:16:21.870000
# SpeedI1                                    213.0
# SpeedI2                                    199.0
# SpeedFL                                    258.0
# SpeedST                                    271.0
# ...

# %%
lap.get_telemetry()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[17], line 1
# ----> 1 lap.get_telemetry()
#
# File c:\Users\HP\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\fastf1\core.py:3619, in Lap.get_telemetry(self, frequency)
#    3617 car_data = car_data.add_distance().add_relative_distance()
#    3618 car_data = car_data.merge_channels(drv_ahead, frequency=frequency)
# -> 3619 merged = pos_data.merge_channels(car_data, frequency=frequency)
#    3620 return merged.slice_by_lap(self, interpolate_edges=True)
#
# File c:\Users\HP\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\fastf1\core.py:441, in Telemetry.merge_channels(self, other, frequency)
#     392 """Merge telemetry objects containing different telemetry channels.
#     393
#     394 The two objects don't need to have a common time base. The data will
# ...

# %%
print(fastf1.__version__)
# Out:
# 3.8.3

# %%
car_data = lap.get_car_data()

car_data.columns
# Out:
# Index(['Date', 'RPM', 'Speed', 'nGear', 'Throttle', 'Brake', 'DRS', 'Source',
#        'Time', 'SessionTime'],
#       dtype='object')

# %%
pos_data = lap.get_pos_data()

pos_data.columns
# Out:
# RangeIndex(start=0, stop=0, step=1)

# %%
car_data.head()
# Out:
#                      Date      RPM  Speed  nGear  Throttle  Brake  DRS Source  \
# 0 2026-06-07 15:23:00.672  11679.0  263.0      6     100.0  False    0    car
# 1 2026-06-07 15:23:00.872  11824.0  265.0      6     100.0  False    0    car
# 2 2026-06-07 15:23:01.072  11905.0  267.0      6     100.0  False    0    car
# 3 2026-06-07 15:23:01.232  11870.0  267.0      6     100.0  False    0    car
# 4 2026-06-07 15:23:01.392  11911.0  268.0      6     100.0  False    0    car
#
#                     Time            SessionTime
# 0 0 days 00:00:00.054000 0 days 03:15:08.413000
# 1 0 days 00:00:00.254000 0 days 03:15:08.613000
# 2 0 days 00:00:00.454000 0 days 03:15:08.813000
# 3 0 days 00:00:00.614000 0 days 03:15:08.973000
# 4 0 days 00:00:00.774000 0 days 03:15:09.133000

# %%
print(pos_data.shape)
# Out:
# (0, 0)

# %%
print(lap['Driver'])
print(lap['LapNumber'])
# Out:
# ANT
# 76.0

# %%
lap2 = session.laps.iloc[100]

print(lap2['Driver'])
print(lap2['LapNumber'])

pos = lap2.get_pos_data()

print(pos.shape)
# Out:
# GAS
# 57.0
# (0, 0)

# %%
session.event
# Out:
# RoundNumber                                                          6
# Country                                                         Monaco
# Location                                                   Monte Carlo
# OfficialEventName    FORMULA 1 LOUIS VUITTON GRAND PRIX DE MONACO 2026
# EventDate                                          2026-06-07 00:00:00
# EventName                                            Monaco Grand Prix
# EventFormat                                               conventional
# Session1                                                    Practice 1
# Session1Date                                 2026-06-05 13:30:00+02:00
# Session1DateUtc                                    2026-06-05 11:30:00
# Session2                                                    Practice 2
# Session2Date                                 2026-06-05 17:00:00+02:00
# Session2DateUtc                                    2026-06-05 15:00:00
# ...

# %%
print(session.car_data.keys())
# Out:
# dict_keys(['12', '44', '10', '6', '81', '30', '41', '23', '31', '14', '5', '63', '27', '43', '11', '55', '16', '18', '1', '87', '77', '3'])

# %%
print(session.pos_data.keys())
# Out:
# dict_keys(['12', '44', '10', '6', '81', '30', '41', '23', '31', '14', '5', '63', '27', '43', '11', '55', '16', '18', '1', '87', '77', '3'])

# %%
lap = session.laps.pick_fastest()

print(lap['Driver'])
print(lap['LapNumber'])

pos_data = lap.get_pos_data()

print(pos_data.shape)
# Out:
# ANT
# 76.0
# (0, 0)

# %%
driver = lap['DriverNumber']

print(session.pos_data[driver].head())
print(session.pos_data[driver].shape)
# Out:
#                      Date   Status    X    Y    Z Source  \
# 0 2026-06-07 12:08:38.424  OnTrack  0.0  0.0  0.0    pos
# 1 2026-06-07 12:08:38.644  OnTrack  0.0  0.0  0.0    pos
# 2 2026-06-07 12:08:38.844  OnTrack  0.0  0.0  0.0    pos
# 3 2026-06-07 12:08:39.024  OnTrack  0.0  0.0  0.0    pos
# 4 2026-06-07 12:08:39.184  OnTrack  0.0  0.0  0.0    pos
#
#                     Time            SessionTime
# 0 0 days 00:00:46.165000 0 days 00:00:46.165000
# 1 0 days 00:00:46.385000 0 days 00:00:46.385000
# 2 0 days 00:00:46.585000 0 days 00:00:46.585000
# 3 0 days 00:00:46.765000 0 days 00:00:46.765000
# 4 0 days 00:00:46.925000 0 days 00:00:46.925000
# (8087, 8)

# %%
lap = session.laps.pick_fastest()

print("Driver:", lap["Driver"])
print("Lap Number:", lap["LapNumber"])
print("Lap Start:", lap["LapStartTime"])
print("Lap Time:", lap["LapTime"])

pos = lap.get_pos_data()

print(pos.shape)
print(pos.head())
# Out:
# Driver: ANT
# Lap Number: 76.0
# Lap Start: 0 days 03:15:08.359000
# Lap Time: 0 days 00:01:13.481000
# (0, 0)
# Empty DataFrame
# Columns: []
# Index: []
